# %%
import time
import torch
import torch.nn as nn
from torch.nn import functional as F
from datasets import load_dataset
from transformers import GPT2Tokenizer

# Hyperparameters:

# No. of training examples processed at once.
batch_size = 8
# Context length.
block_size = 512
# Max no of iterations.
max_iters = 1500
# No of iterations after which evaluation happens.
eval_interval = 300
# Step-size during gradient descent.
learning_rate = 3e-4
# Choosing a gpu or a cpu.
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# No of batches to use while evaluating the validation loss. Since each batch has 8 training examples so in total 8 * 50 = 400 examples are being used to calculate the validation loss.
eval_iters = 50
# Dimension of each token in the vector space.
n_embd = 128
# No of attention heads required while implementing Multi-Head attention. Each head shall get n_embd / n_head = 128 / 2 = 32 dimensions.
n_head = 4
# No of transformer blocks
n_layer = 4
# randomly switches of 20% of the neurons at each step to prevent overfitting.
dropout = 0.2

# Attention type:
# For standard MHA: n_kv_head = n_head
# For MQA: n_kv_head = 1
# For GQA: 1 < n_kv_head < n_head

n_kv_head = 1   # MQA example
# n_kv_head = 2 # GQA example
# ------------

# To make random operations reproducible.
torch.manual_seed(1337)

# loading the WikiText-2 dataset.
dataset = load_dataset("wikitext", "wikitext-2-raw-v1")
# loading the GPT2 tokenizer.
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# GPT2 tokenizer by default has no padding, padding is done to make the
# sentences of the same length. We are using the "EOS"(End of Sequence) token for padding.
tokenizer.pad_token = tokenizer.eos_token

# Tokenize function:
def tokenize_function(examples):
    return tokenizer(examples["text"])

# Tokenize the whole dataset:
tokenized_datasets = dataset.map(
    tokenize_function,
    # To tokenize a batch_size no of examples at once.
    batched=True,
    # After tokenization we remove the raw text.
    remove_columns=["text"]
)

# Converts to one long token sequence
train_ids = []
for item in tokenized_datasets["train"]["input_ids"]:
    train_ids.extend(item)

val_ids = []
for item in tokenized_datasets["validation"]["input_ids"]:
    val_ids.extend(item)

# convert to tensors
train_data = torch.tensor(train_ids, dtype=torch.long)
val_data = torch.tensor(val_ids, dtype=torch.long)

# vocabulary size
vocab_size = tokenizer.vocab_size

# decode function
decode = lambda l: tokenizer.decode(l)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# To evalulate how well the model is performing on training and validation data.
@torch.no_grad() # Tells PyTorch to not compute the gradients cause during evaluation we are only measuring loss and not training.
# Computes average training and validation loss.
def estimate_loss():
    out = {}
    model.eval() # Going to evaluation mode, dropout doesnt happen during evaluation mode.
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train() # Back to training mode.
    return out

class MultiQueryAttention(nn.Module):

    def __init__(self, num_heads, num_kv_heads, head_size):
        super().__init__()

        assert num_heads % num_kv_heads == 0, \
            # n_head must be divisible by n_kv_head

        self.num_heads = num_heads
        self.num_kv_heads = num_kv_heads
        self.head_size = head_size

        # Query projection for ALL query heads
        self.query = nn.Linear(
            n_embd,
            num_heads * head_size,
            bias=False
        )

        # Shared/grouped Key & Value projections
        self.key = nn.Linear(
            n_embd,
            num_kv_heads * head_size,
            bias=False
        )

        self.value = nn.Linear(
            n_embd,
            num_kv_heads * head_size,
            bias=False
        )

        # Output projection
        self.proj = nn.Linear(
            num_heads * head_size,
            n_embd
        )

        self.dropout = nn.Dropout(dropout)

        # causal mask
        self.register_buffer(
            "tril",
            torch.tril(torch.ones(block_size, block_size))
        )

    def forward(self, x):

        B, T, C = x.shape

        # Queries
        q = self.query(x)
        q = q.view(
            B,
            T,
            self.num_heads,
            self.head_size
        ).transpose(1, 2)
        # (B, n_head, T, head_size)

        # Keys
        k = self.key(x)
        k = k.view(
            B,
            T,
            self.num_kv_heads,
            self.head_size
        ).transpose(1, 2)
        # (B, n_kv_head, T, head_size)

        # Values
        v = self.value(x)
        v = v.view(
            B,
            T,
            self.num_kv_heads,
            self.head_size
        ).transpose(1, 2)
        # (B, n_kv_head, T, head_size)

        # Expand KV heads to match query heads
        if self.num_kv_heads != self.num_heads:

            repeat_factor = self.num_heads // self.num_kv_heads

            k = k.repeat_interleave(
                repeat_factor,
                dim=1
            )

            v = v.repeat_interleave(
                repeat_factor,
                dim=1
            )

        # k,v now:
        # (B, n_head, T, head_size)

        # Attention
        wei = (
            q @ k.transpose(-2, -1)
        ) * (self.head_size ** -0.5)

        wei = wei.masked_fill(
            self.tril[:T, :T] == 0,
            float('-inf')
        )

        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)

        out = wei @ v
        # (B, n_head, T, head_size)

        # Recombine heads
        out = out.transpose(1, 2).contiguous()
        out = out.view(
            B,
            T,
            self.num_heads * self.head_size
        )

        out = self.proj(out)
        out = self.dropout(out)

        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            # Expands the total dimensions from n_embd -> 4 * n_embd. (here: 128--> 512)
            nn.Linear(n_embd, 4 * n_embd),
            # ReLU(x) = max(0, x)
            nn.ReLU(),
            # Compress back to n_embd dimensions.
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiQueryAttention(n_head, n_kv_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        # Layernorms, normalizes activations to stabilize training.
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        # "Residual Connection", instead of replacing the old representations completely
        # the model learns the corrections and the refinements.
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # Final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)
        self.apply(self._init_weights) # Initializing with random small weights(centered at 0 and std dev = 0.02) and biases.

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # "idx" is the full sequence generated so far.
        for _ in range(max_new_tokens):
            # "idx_cond" is the last "block_size" no of tokens in idx.
            idx_cond = idx[:, -block_size:]
            # Get the predictions.
            logits, loss = self(idx_cond)
            # Focus only on the last time step.
            logits = logits[:, -1, :] # Becomes (B, C).
            # Apply softmax to get probabilities.
            probs = F.softmax(logits, dim=-1) # (B, C)
            # Sample from the distribution.
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # Append sampled index to the running sequence.
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = GPTLanguageModel().to(device)
# Print the number of parameters in the model.
print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')

# Create a PyTorch optimizer.
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

start_time = time.time()
last_eval_iter = 0

for iter in range(max_iters):

    # Every once in a while evaluate the loss on train and val sets.
    if iter % eval_interval == 0 or iter == max_iters - 1:

        if torch.cuda.is_available():
          torch.cuda.reset_peak_memory_stats()

        losses = estimate_loss()

        if torch.cuda.is_available():
          torch.cuda.synchronize()

        elapsed = time.time() - start_time

        iterations_done = iter - last_eval_iter
        tokens_processed = iterations_done * batch_size * block_size

        throughput = 0 if iterations_done == 0 else tokens_processed / elapsed

        # Perplexity
        train_ppl = torch.exp(losses['train'])
        val_ppl = torch.exp(losses['val'])

        print(f"\nstep {iter}:")
        print(f"train ppl: {train_ppl:.2f}")
        print(f"val ppl: {val_ppl:.2f}")
        print(f"throughput: {throughput:.2f} tokens/sec")

        if torch.cuda.is_available():
          memory = torch.cuda.max_memory_allocated() / 1024**3
          print(f"gpu memory: {memory:.2f} GB")

        start_time = time.time()
        last_eval_iter = iter

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# ---------------- INFERENCE BENCHMARK ----------------

model.eval()

gen_tokens = 200

context = torch.randint(
    0,
    vocab_size,
    (1, block_size),
    device=device
)

if torch.cuda.is_available():
    torch.cuda.synchronize()

start = time.time()

with torch.no_grad():
    model.generate(context, max_new_tokens=gen_tokens)

if torch.cuda.is_available():
    torch.cuda.synchronize()

elapsed = time.time() - start

print("\nInference Benchmark:")
print(f"Inference tokens/sec: {gen_tokens / elapsed:.2f}")
print(f"Latency per token: {elapsed / gen_tokens:.4f} sec")
# ------------------------------------------------------

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(model.generate(context, max_new_tokens=500)[0].tolist()))
#open('more.txt', 'w').write(decode(m.generate(context, max_new_tokens=10000)[0].tolist()))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# wikitext-2-raw-v1/test-00000-of-00001.pa(…):   0%|          | 0.00/733k [00:00<?, ?B/s]
# wikitext-2-raw-v1/train-00000-of-00001.p(…):   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# wikitext-2-raw-v1/validation-00000-of-00(…):   0%|          | 0.00/657k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Map:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Map:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3760 [00:00<?, ? examples/s]
# 13.675089 M parameters
#
# step 0:
# train ppl: 52045.11
# val ppl: 52109.43
# throughput: 0.00 tokens/sec
# gpu memory: 2.37 GB
#
# step 300:
# train ppl: 841.28
# val ppl: 871.33
# throughput: 34881.85 tokens/sec
# gpu memory: 3.30 GB
#
# step 600:
# train ppl: 524.12
# val ppl: 587.93
# throughput: 32384.97 tokens/sec
# gpu memory: 3.30 GB
#
# step 900:
# train ppl: 390.66
# val ppl: 483.02
# throughput: 29137.37 tokens/sec
# gpu memory: 3.30 GB
#
# step 1200:
# train ppl: 324.32
# val ppl: 445.16
# throughput: 30451.69 tokens/sec
# gpu memory: 3.30 GB
#
# step 1499:
# train ppl: 284.41
# val ppl: 395.48
# throughput: 29919.86 tokens/sec
# gpu memory: 3.30 GB
#
# Inference Benchmark:
# Inference tokens/sec: 177.97
# Latency per token: 0.0056 sec
# ! – 400 metres ( 20 months to establish days ) . The 1960s State Ment pour and fighting , the 3rd Mountgar in the roof , appointed tribes at heavy government and prompt railway reached 629 , after the kingswell launched in Croatia , and support to be collected . In Michigan , the British forces in the Easthibition levels in it had released to Central Penodon nor is full casualties with a number of the bombardment of an inspiration in Maryland Act and others and was ordered so : dissteps into May 2005 and gave Khros College andight , but there but probably to run to be Teada are not been done by the identification , Warriors of again . The city of the summer of the Seafoes . Also from the ancient Commission and a limited number of the 2009 .
#
#  = injected in the ambassador for hype , it was impossible to spread , Agine 's lower saying that the other strength in 1200 , Bra Roosevelt in whole aspects , first term media of his daughter , initially took life continued his explicit modern service to Nconith opened to come over the Cif under subush departed . The Milk Under each time won the deduction , William GrimesScan from the city for Antoni Island with his death or at the fountain was��rell dbikeaku , explosion in an apparent by fast .
#  decades of Par BLrruez Council since Graham in Peggy R Symbulgh 's brilliant generals , Penny of Recreation =
#  As well performed into a Jun " Trans borne As of 1863 radius : Haíors to the engagement and aftermath of KOC , although he had served as a steep had become " United States opportunities in 1936 plotted , they extremely present All species .
#  Aston Georg of Le1 , one it , Wats .
#  Synai , where he had previously officially moved to Ceres 's , the
#  The new names of their dancing no history songs at the Royal Army Thousandth century that most have in $ 26 . This is occupied by Metn In December 1 March the internal refuses the one structure . The camp , Lord I 't been quite considered a belly , the first term £ 551 , writing for the train to the recorded more Chris Réey .
# cella . His guards in repertoire aired on the moon and Type 8 on 9th century Now .  Evening called Veravson often also since 1987 . The extensive jin , British capital of the handful themes bootirthain . At the east .

# %%
import time
import torch
import torch.nn as nn
from torch.nn import functional as F
from datasets import load_dataset
from transformers import GPT2Tokenizer

# Hyperparameters:

# No. of training examples processed at once.
batch_size = 8
# Context length.
block_size = 1024
# Max no of iterations.
max_iters = 1500
# No of iterations after which evaluation happens.
eval_interval = 300
# Step-size during gradient descent.
learning_rate = 3e-4
# Choosing a gpu or a cpu.
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# No of batches to use while evaluating the validation loss. Since each batch has 8 training examples so in total 8 * 50 = 400 examples are being used to calculate the validation loss.
eval_iters = 50
# Dimension of each token in the vector space.
n_embd = 128
# No of attention heads required while implementing Multi-Head attention. Each head shall get n_embd / n_head = 128 / 2 = 32 dimensions.
n_head = 4
# No of transformer blocks
n_layer = 4
# randomly switches of 20% of the neurons at each step to prevent overfitting.
dropout = 0.2

# Attention type:
# For standard MHA: n_kv_head = n_head
# For MQA: n_kv_head = 1
# For GQA: 1 < n_kv_head < n_head

n_kv_head = 1   # MQA example
# n_kv_head = 2 # GQA example
# ------------

# To make random operations reproducible.
torch.manual_seed(1337)

# loading the WikiText-2 dataset.
dataset = load_dataset("wikitext", "wikitext-2-raw-v1")
# loading the GPT2 tokenizer.
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# GPT2 tokenizer by default has no padding, padding is done to make the
# sentences of the same length. We are using the "EOS"(End of Sequence) token for padding.
tokenizer.pad_token = tokenizer.eos_token

# Tokenize function:
def tokenize_function(examples):
    return tokenizer(examples["text"])

# Tokenize the whole dataset:
tokenized_datasets = dataset.map(
    tokenize_function,
    # To tokenize a batch_size no of examples at once.
    batched=True,
    # After tokenization we remove the raw text.
    remove_columns=["text"]
)

# Converts to one long token sequence
train_ids = []
for item in tokenized_datasets["train"]["input_ids"]:
    train_ids.extend(item)

val_ids = []
for item in tokenized_datasets["validation"]["input_ids"]:
    val_ids.extend(item)

# convert to tensors
train_data = torch.tensor(train_ids, dtype=torch.long)
val_data = torch.tensor(val_ids, dtype=torch.long)

# vocabulary size
vocab_size = tokenizer.vocab_size

# decode function
decode = lambda l: tokenizer.decode(l)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# To evalulate how well the model is performing on training and validation data.
@torch.no_grad() # Tells PyTorch to not compute the gradients cause during evaluation we are only measuring loss and not training.
# Computes average training and validation loss.
def estimate_loss():
    out = {}
    model.eval() # Going to evaluation mode, dropout doesnt happen during evaluation mode.
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train() # Back to training mode.
    return out

class MultiQueryAttention(nn.Module):
    """
    Supports:
    - MHA  : n_kv_head == n_head
    - MQA  : n_kv_head == 1
    - GQA  : 1 < n_kv_head < n_head
    """

    def __init__(self, num_heads, num_kv_heads, head_size):
        super().__init__()

        assert num_heads % num_kv_heads == 0, \
            "n_head must be divisible by n_kv_head"

        self.num_heads = num_heads
        self.num_kv_heads = num_kv_heads
        self.head_size = head_size

        # Query projection for ALL query heads
        self.query = nn.Linear(
            n_embd,
            num_heads * head_size,
            bias=False
        )

        # Shared/grouped Key & Value projections
        self.key = nn.Linear(
            n_embd,
            num_kv_heads * head_size,
            bias=False
        )

        self.value = nn.Linear(
            n_embd,
            num_kv_heads * head_size,
            bias=False
        )

        # Output projection
        self.proj = nn.Linear(
            num_heads * head_size,
            n_embd
        )

        self.dropout = nn.Dropout(dropout)

        # causal mask
        self.register_buffer(
            "tril",
            torch.tril(torch.ones(block_size, block_size))
        )

    def forward(self, x):

        B, T, C = x.shape

        # Queries
        q = self.query(x)
        q = q.view(
            B,
            T,
            self.num_heads,
            self.head_size
        ).transpose(1, 2)
        # (B, n_head, T, head_size)

        # Keys
        k = self.key(x)
        k = k.view(
            B,
            T,
            self.num_kv_heads,
            self.head_size
        ).transpose(1, 2)
        # (B, n_kv_head, T, head_size)

        # Values
        v = self.value(x)
        v = v.view(
            B,
            T,
            self.num_kv_heads,
            self.head_size
        ).transpose(1, 2)
        # (B, n_kv_head, T, head_size)

        # Expand KV heads to match query heads
        if self.num_kv_heads != self.num_heads:

            repeat_factor = self.num_heads // self.num_kv_heads

            k = k.repeat_interleave(
                repeat_factor,
                dim=1
            )

            v = v.repeat_interleave(
                repeat_factor,
                dim=1
            )

        # k,v now:
        # (B, n_head, T, head_size)

        # Attention
        wei = (
            q @ k.transpose(-2, -1)
        ) * (self.head_size ** -0.5)

        wei = wei.masked_fill(
            self.tril[:T, :T] == 0,
            float('-inf')
        )

        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)

        out = wei @ v
        # (B, n_head, T, head_size)

        # Recombine heads
        out = out.transpose(1, 2).contiguous()
        out = out.view(
            B,
            T,
            self.num_heads * self.head_size
        )

        out = self.proj(out)
        out = self.dropout(out)

        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            # Expands the total dimensions from n_embd -> 4 * n_embd. (here: 128--> 512)
            nn.Linear(n_embd, 4 * n_embd),
            # ReLU(x) = max(0, x)
            nn.ReLU(),
            # Compress back to n_embd dimensions.
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiQueryAttention(n_head, n_kv_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        # Layernorms, normalizes activations to stabilize training.
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        # "Residual Connection", instead of replacing the old representations completely
        # the model learns the corrections and the refinements.
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # Final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)
        self.apply(self._init_weights) # Initializing with random small weights(centered at 0 and std dev = 0.02) and biases.

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # "idx" is the full sequence generated so far.
        for _ in range(max_new_tokens):
            # "idx_cond" is the last "block_size" no of tokens in idx.
            idx_cond = idx[:, -block_size:]
            # Get the predictions.
            logits, loss = self(idx_cond)
            # Focus only on the last time step.
            logits = logits[:, -1, :] # Becomes (B, C).
            # Apply softmax to get probabilities.
            probs = F.softmax(logits, dim=-1) # (B, C)
            # Sample from the distribution.
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # Append sampled index to the running sequence.
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = GPTLanguageModel().to(device)
# Print the number of parameters in the model.
print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')

# Create a PyTorch optimizer.
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

start_time = time.time()
last_eval_iter = 0

for iter in range(max_iters):

    # Every once in a while evaluate the loss on train and val sets.
    if iter % eval_interval == 0 or iter == max_iters - 1:

        if torch.cuda.is_available():
          torch.cuda.reset_peak_memory_stats()

        losses = estimate_loss()

        if torch.cuda.is_available():
          torch.cuda.synchronize()

        elapsed = time.time() - start_time

        iterations_done = iter - last_eval_iter
        tokens_processed = iterations_done * batch_size * block_size

        throughput = 0 if iterations_done == 0 else tokens_processed / elapsed

        # Perplexity
        train_ppl = torch.exp(losses['train'])
        val_ppl = torch.exp(losses['val'])

        print(f"\nstep {iter}:")
        print(f"train ppl: {train_ppl:.2f}")
        print(f"val ppl: {val_ppl:.2f}")
        print(f"throughput: {throughput:.2f} tokens/sec")

        if torch.cuda.is_available():
          memory = torch.cuda.max_memory_allocated() / 1024**3
          print(f"gpu memory: {memory:.2f} GB")

        start_time = time.time()
        last_eval_iter = iter

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# ---------------- INFERENCE BENCHMARK ----------------

model.eval()

gen_tokens = 200

context = torch.randint(
    0,
    vocab_size,
    (1, block_size),
    device=device
)

if torch.cuda.is_available():
    torch.cuda.synchronize()

start = time.time()

with torch.no_grad():
    model.generate(context, max_new_tokens=gen_tokens)

if torch.cuda.is_available():
    torch.cuda.synchronize()

elapsed = time.time() - start

print("\nInference Benchmark:")
print(f"Inference tokens/sec: {gen_tokens / elapsed:.2f}")
print(f"Latency per token: {elapsed / gen_tokens:.4f} sec")
# ------------------------------------------------------

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(model.generate(context, max_new_tokens=500)[0].tolist()))
#open('more.txt', 'w').write(decode(m.generate(context, max_new_tokens=10000)[0].tolist()))
# Out:
# 13.740625 M parameters
#
# step 0:
# train ppl: 50934.27
# val ppl: 50995.36
# throughput: 0.00 tokens/sec
# gpu memory: 5.56 GB
#
# step 300:
# train ppl: 748.86
# val ppl: 791.48
# throughput: 25834.33 tokens/sec
# gpu memory: 6.38 GB
#
# step 600:
# train ppl: 440.17
# val ppl: 531.57
# throughput: 26122.81 tokens/sec
# gpu memory: 6.38 GB
#
# step 900:
# train ppl: 345.91
# val ppl: 443.17
# throughput: 26134.03 tokens/sec
# gpu memory: 6.38 GB
#
# step 1200:
# train ppl: 280.95
# val ppl: 387.67
# throughput: 26123.69 tokens/sec
# gpu memory: 6.38 GB
#
# step 1499:
# train ppl: 231.56
# val ppl: 349.32
# throughput: 26006.08 tokens/sec
# gpu memory: 6.38 GB
#
# Inference Benchmark:
# Inference tokens/sec: 99.12
# Latency per token: 0.0101 sec
# !ops Zoo , examines reward for Sovonistic Jews . The Malouberger appear to collect the most important lend the " long water sh won the tremendous damage sensation of the approach allowed the substantial military . The Statistics , they started money for wheat . q ( 1852 , on the evening Conservation Liam acres ( 2000 , ask Venus .
#  =
#  The settlers to bring the rights , and the point for London , especially identified enemies stabilized ) = =
#  On the town did not gather his ones , association with their earthare ' confidence ) , d 's circuit could neutral obligation for the death in London ( 2013 – 290 : 2962 century and major surface British government final idea of the northern 17 April 2010 39 longevity in a world . Overall , the supply of the end in the night . They then designed Monsos Road . Three years , Kirk : 00 ) to escape the town of the Nry , players , that temporary recounted a comeback . The water finitions , 1927 , in their actor , the Oldham Baux , and were then called Redirects body was ascertain , they had been centimetres ; the planned to occupy the upper @-@ scale , Vermont . At the Type 7th Battalion ( 1921 Road .
#  sport of the first by the highest battle goal by the collision with the same issue , being an timed concentrated in the Kurvriatic culture =
#  Currently , Eliquu ) of the Rugby Bay Navy 's successor , believed that large oxidation The patron of Ungulell also the unit to be 266 @-@ 200 cm ) , in the workshop , with animals - Keander 's navigation , the church , the CNS @-@ vertical and a declaration is very most of the officers and Gstaore in response to the beginning of violence . Janeiro 's aerinn , North Carolina . An objective ; it won the 19th @-@ 000 hourus ( 2012 , who was not considered edges almost having the sky added that their hearted was not alter the Mlimre River . One has present in a yeah , given their railway panels in the First virus . Allied Olympic 3 cm ) process for quick leadership , aftertto of the rural taking light and loyalty through sexes have officially used available " one and he said that long @. encouraged from OH / open with promotion from the boundary between £ 8 % : 30 . He was favorable a molecular atmosphere , when two Ages deliberately amended a youthful raids in 2015 . This
